# %%
import requests
import pandas as pd
import os

# %% [markdown]
# ### Download data

# %%
# data path
url = 'https://www.datos.gov.co/resource/yvb2-ppaa.csv'

# %%
#  Just run once
# response = requests.get(url)
# print(response)
# response.raise_for_status()
# Out:
# <Response [200]>

# %%
path = r'D:\0_Respaldo\0_Proyectos_2024\ML_proyects\tas_interes\data\raw'

# %%
filename = os.path.join(path, 'tas.csv')
with open(filename, 'wb') as file:
            file.write(response.content)

# %% [markdown]
# ### Eda

# %%
#csv_file = response
data = pd.read_csv(r'D:\0_Respaldo\0_Proyectos_2024\ML_proyects\tas_interes\data\raw\tas.csv')

# %%
data.head(3)
# Out:
#    tipoentidad  codigoentidad                        nombreentidad  \
# 0           32              1  Cooperativa Financiera De Antioquia
# 1            1              7                          Bancolombia
# 2            1             23                   Banco De Occidente
#
#                 fechacorte  unidad_de_captura                nombre  \
# 0  2019-02-01T00:00:00.000                 11  CREDITOS COMERCIALES
# 1  2014-09-26T00:00:00.000                 11  CREDITOS COMERCIALES
# 2  2007-05-04T00:00:00.000                  9   CREDITOS DE CONSUMO
#
#                   tipo  subcuenta             nombre_sub  tasaefectivaanual  \
# 0            ORDINARIO          5      ENTRE 1 Y 30 DIAS              28.34
# 1            ORDINARIO         40     A MAS DE 1825 DIAS              11.58
# 2  CREDITOS DE CONSUMO         20  ENTRE 366 Y 1095 DIAS              20.40
#
#         montos  num_creditos_desembolsados
# 0    593975.00                          47
# ...

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tipoentidad                 1000 non-null   int64
#  1   codigoentidad               1000 non-null   int64
#  2   nombreentidad               1000 non-null   object
#  3   fechacorte                  1000 non-null   object
#  4   unidad_de_captura           1000 non-null   int64
#  5   nombre                      1000 non-null   object
#  6   tipo                        1000 non-null   object
#  7   subcuenta                   1000 non-null   int64
#  8   nombre_sub                  1000 non-null   object
#  9   tasaefectivaanual           1000 non-null   float64
#  10  montos                      1000 non-null   float64
#  11  num_creditos_desembolsados  1000 non-null   int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 93.9+ KB
# ...

# %%
data.isnull
# Out:
# <bound method DataFrame.isnull of      tipoentidad  codigoentidad                        nombreentidad  \
# 0             32              1  Cooperativa Financiera De Antioquia
# 1              1              7                          Bancolombia
# 2              1             23                   Banco De Occidente
# 3              1             13                        Bbva Colombia
# 4              1             34                          Bansuperior
# ..           ...            ...                                  ...
# 995            1             30                    Banco Caja Social
# 996            1              5   Banco Cafetero S.A. En Liquidación
# 997            1             49                            Av Villas
# 998            1             14                       Helm Bank S.A.
# 999            1             39                     Banco Davivienda
#
#                   fechacorte  unidad_de_captura                        nombre  \
# ...

# %%
data.drop_duplicates
data.dropna
# Out:
# <bound method DataFrame.dropna of      tipoentidad  codigoentidad                        nombreentidad  \
# 0             32              1  Cooperativa Financiera De Antioquia
# 1              1              7                          Bancolombia
# 2              1             23                   Banco De Occidente
# 3              1             13                        Bbva Colombia
# 4              1             34                          Bansuperior
# ..           ...            ...                                  ...
# 995            1             30                    Banco Caja Social
# 996            1              5   Banco Cafetero S.A. En Liquidación
# 997            1             49                            Av Villas
# 998            1             14                       Helm Bank S.A.
# 999            1             39                     Banco Davivienda
#
#                   fechacorte  unidad_de_captura                        nombre  \
# ...

# %%
data.shape
# Out:
# (1000, 12)

# %%
data.info
# Out:
# <bound method DataFrame.info of      tipoentidad  codigoentidad                        nombreentidad  \
# 0             32              1  Cooperativa Financiera De Antioquia
# 1              1              7                          Bancolombia
# 2              1             23                   Banco De Occidente
# 3              1             13                        Bbva Colombia
# 4              1             34                          Bansuperior
# ..           ...            ...                                  ...
# 995            1             30                    Banco Caja Social
# 996            1              5   Banco Cafetero S.A. En Liquidación
# 997            1             49                            Av Villas
# 998            1             14                       Helm Bank S.A.
# 999            1             39                     Banco Davivienda
#
#                   fechacorte  unidad_de_captura                        nombre  \
# ...

# %%
data.sample(15)
# Out:
#      tipoentidad  codigoentidad                             nombreentidad  \
# 163            1              7                               Bancolombia
# 577           32              4                        Cotrafa Financiera
# 203            4             23                                Serfinansa
# 933            1             14                            Helm Bank S.A.
# 982           32              1       Cooperativa Financiera De Antioquia
# 640            1             42             Banco Colpatria, "Scotiabank"
# 31             1             47  Conavi Banco Comercial Y De Ahorros S.A.
# 215            1             23                        Banco De Occidente
# 164            1             10                                 Banco Gnb
# 125            1             39                          Banco Davivienda
# 374            1             23                        Banco De Occidente
# 506            1              1                           Banco De Bogota
# ...

# %%
data['fechacorte'].describe()
# Out:
# count                        1000
# unique                        650
# top       2014-01-03T00:00:00.000
# freq                            5
# Name: fechacorte, dtype: object
